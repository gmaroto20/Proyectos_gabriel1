# %%
# el comando text sirve para crear un cuadro de texto que coja mucho espacio

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe)
texcomentario.grid(row=4,column=1,padx=10,pady=10)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

raiz.mainloop()

# %%
#vamos a dimensionar el nuevo cuadro, pq sale enorme

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

raiz.mainloop()

# %%
# a continuacion le vamos a añadir un scroll para poder subir y bajar con el texto (Scrollbar())

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

scrollvert=Scrollbar(miframe,command=texcomentario.yview)
scrollvert.grid(row=4,column=2)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

raiz.mainloop()

# %%
#se puede mejorar este scroll (mismo largo que el texto y posicionarse con el texto)
#mismo largo: sticky="nsew" norte,sur este  oeste
# que se posicione: configuramos el texto, texcomentario.grid(yscrollcommand=scrollvert.set)

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

scrollvert=Scrollbar(miframe,command=texcomentario.yview)
scrollvert.grid(row=4,column=2,sticky="nsew")

texcomentario.config(yscrollcommand=scrollvert.set)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

raiz.mainloop()

# %%
#vamos a crear un boton y darle una orden (Button(miframe,command= codigoboton))
#las ordenes se introducen con el parametro command

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

scrollvert=Scrollbar(miframe,command=texcomentario.yview)
scrollvert.grid(row=4,column=2,sticky="nsew")

texcomentario.config(yscrollcommand=scrollvert.set)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

    
botonenvio=Button(miframe,text="envio",command=codigoboton)
botonenvio.grid(row=8,column=1)


raiz.mainloop()

# %%
#la funcion que vamos a crear (codigoboton ) va a ordenar que al pulsar este se introduzca
#un  nombre en el cuadro de texto: "nombre",primero creamos una funcion(codigoboton) y le asignamos
#el metodo minombre.set("Gabriel")
#el metodo .set sirve para enviar las ordenes a donde queramos, en este caso a un cuadro de texto
#a traves de la variable minombre que debe estar definida previamente (metodo StringVar())

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()


cuadronombre=Entry(miframe)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center",bg="blue")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

scrollvert=Scrollbar(miframe,command=texcomentario.yview)
scrollvert.grid(row=4,column=2,sticky="nsew")

texcomentario.config(yscrollcommand=scrollvert.set)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Pasword:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)

def codigoboton():
    minombre.set("Gabriel")
    
botonenvio=Button(miframe,text="envio",command=codigoboton)
botonenvio.grid(row=8,column=1)



raiz.mainloop()

# %%
#pero previamente debemos introducir la variable minombre asociada al cuadro de texto donde 
#se encuentre este (cuadronombre), para ello la asociamos a una cadena de caracteres StringVar()
#con esto le decimos que se trata de una cadena de caracteres y luego la introducimos en el Entry
# con el argumento texvariable=

# %%
from tkinter import *

raiz=Tk()

miframe=Frame(raiz,width="1200",height="600")
miframe.pack()

minombre=StringVar()

cuadronombre=Entry(miframe,textvariable=minombre)
cuadronombre.grid(row=0,column=1,padx=10,pady=10)
cuadronombre.config(fg="red",justify="center")

cuadropass=Entry(miframe)
cuadropass.grid(row=1,column=1,padx=10,pady=10)
cuadropass.config(fg="red",justify="center",show="*")

cuadroapellido=Entry(miframe)
cuadroapellido.grid(row=2,column=1,padx=10,pady=10)
cuadroapellido.config(fg="red",justify="center")

cuadrodireccion=Entry(miframe)
cuadrodireccion.grid(row=3,column=1,padx=10,pady=10)
cuadrodireccion.config(fg="red",justify="center")

texcomentario=Text(miframe,width="15",height="15")
texcomentario.grid(row=4,column=1,padx=10,pady=10)

scrollvert=Scrollbar(miframe,command=texcomentario.yview)
scrollvert.grid(row=4,column=2,sticky="nsew")

texcomentario.config(yscrollcommand=scrollvert.set)

nombrelabel=Label(miframe,text="Nombre:")
nombrelabel.grid(row=0,column=0,sticky="e",padx=10,pady=10)

passlabel=Label(miframe,text="Password:")
passlabel.grid(row=1,column=0,sticky="e",padx=10,pady=10)

apellidolabel=Label(miframe,text="Apellido:")
apellidolabel.grid(row=2,column=0,sticky="e",padx=10,pady=10)

direccionlabel=Label(miframe,text="Direccion:")
direccionlabel.grid(row=3,column=0,sticky="e",padx=10,pady=10)

comenlabel=Label(miframe,text="Comentarios:")
comenlabel.grid(row=4,column=0,sticky="e",padx=10,pady=10)
nom=iput("nombre:")
def codigoboton():
    minombre.set(nom)
    
botonenvio=Button(miframe,text="envio",command=codigoboton)
botonenvio.grid(row=8,column=1)

raiz.mainloop()
# Out:
# nombre:pep
