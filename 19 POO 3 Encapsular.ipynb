# %%
# del mismo modo se pueden encapsular los metodos
#vamos a añadir un nuevo metodo (chequeo) que va a chequear antes del arranque

# %%
class coche():
    def __init__(self):
        self.largochasis=250
        self.anchochasis=120
        self.__ruedas=4
        self.enmarcha=False
        
    def arrancar(self,arrancamos):
        self.enmarcha=arrancamos
        if (self.enmarcha):
            return("el coche esta en marcha")
        else:
            return("el coche esta parado")
        
    def estado(self):
        print("el coche tiene ",self.__ruedas, "ruedas,","un ancho de ",self.anchochasis,
              "y","un largo de",self.largochasis)
        
    def chequeo(self):
        print("se va a proceder a chequear el coche")
        self.gasolina="ok"
        self.aceite="ok"
        self.puertas="cerradas"
        if(self.gasolina=="ok" and self.aceite=="ok" and self.puertas=="cerradas"):
            return True
        else:
            return False
        
               
micoche=coche()

print(micoche.arrancar(True))
micoche.estado()

print(".........introducimos un segundo objeto.........")

micoche2=coche()

print(micoche2.arrancar(False))
micoche.estado()

# %%
#ahora hay que ver cuando se hace el chequeo y tiene que ser antes de arrancar
#para ello introducimos el metodo self.chequeo en una variable(chequeado)
#luego establecemos las condiciones de arranque o no, segun nos indique la variable chequeo

# %%
class coche():
    def __init__(self):
        self.largochasis=250
        self.anchochasis=120
        self.__ruedas=4
        self.enmarcha=False
        
    def arrancar(self,arrancamos):
        self.enmarcha=arrancamos
        if (self.enmarcha):
            chequeado=self.chequeo()
        if (self.enmarcha and chequeado):
            return("el coche esta en marcha")
        elif (self.enmarcha and chequeado==False):
            return "algo ha ido mal en el chequeo.No debemos arrancar"
        
        else:
            return("el coche esta parado")
        
    def estado(self):
        print("el coche tiene ",self.__ruedas, "ruedas,","un ancho de ",self.anchochasis,
              "y","un largo de",self.largochasis)
        
    def chequeo(self):
        print("se va a proceder a chequear el coche")
        self.gasolina="ok"
        self.aceite="ok"
        self.puertas="cerradas"
        if(self.gasolina=="ok" and self.aceite=="ok" and self.puertas=="cerradas"):
            return True
        else:
            return False
        
               
micoche=coche()

print(micoche.arrancar(True))
micoche.estado()

print(".........introducimos un segundo objeto.........")

micoche2=coche()

print(micoche2.arrancar(False))
micoche.estado()
# Out:
# se va a proceder a chequear el coche
# el coche esta en marcha
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# .........introducimos un segundo objeto.........
# el coche esta parado
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250

# %%
#si ponemos mal una de las concdiciones del chequeo

# %%
class coche():
    def __init__(self):
        self.largochasis=250
        self.anchochasis=120
        self.__ruedas=4
        self.enmarcha=False
        
    def arrancar(self,arrancamos):
        self.enmarcha=arrancamos
        if (self.enmarcha):
            chequeo=self.chequeo()
        if (self.enmarcha and chequeo):
            return("el coche esta en marcha")
        elif (self.enmarcha and chequeo==False):
            return "algo ha ido mal en el chequeo.No debemos arrancar"
        
        else:
            return("el coche esta parado")
        
    def estado(self):
        print("el coche tiene ",self.__ruedas, "ruedas,","un ancho de ",self.anchochasis,
              "y","un largo de",self.largochasis)
        
    def chequeo(self):
        print("se va a proceder a chequear el coche")
        self.gasolina="ok"
        self.aceite="bajo"
        self.puertas="cerradas"
        if(self.gasolina=="ok" and self.aceite=="ok" and self.puertas=="cerradas"):
            return True
        else:
            return False
        
               
micoche=coche()

print(micoche.arrancar(True))
micoche.estado()

print(".........introducimos un segundo objeto.........")

micoche2=coche()

print(micoche2.arrancar(False))
micoche.estado()
# Out:
# se va a proceder a chequear el coche
# algo ha ido mal en el chequeo.No debemos arrancar
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# .........introducimos un segundo objeto.........
# el coche esta parado
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250

# %%
#pero a este chequeo se puede acceder por fuera, de forma que puede lanzarse una orden en cualquier
#momento y darnos la contradicion de estar chequeando un coche que ya esta en marcha o parado

# %%
class coche():
    def __init__(self):
        self.largochasis=250
        self.anchochasis=120
        self.__ruedas=4
        self.enmarcha=False
        
    def arrancar(self,arrancamos):
        self.enmarcha=arrancamos
        if (self.enmarcha):
            chequeo=self.chequeo()
        if (self.enmarcha and chequeo):
            return("el coche esta en marcha")
        elif (self.enmarcha and chequeo==False):
            return "algo ha ido mal en el chequeo.No debemos arrancar"
        
        else:
            return("el coche esta parado")
        
    def estado(self):
        print("el coche tiene ",self.__ruedas, "ruedas,","un ancho de ",self.anchochasis,
              "y","un largo de",self.largochasis)
        
    def chequeo(self):
        print("se va a proceder a chequear el coche")
        self.gasolina="ok"
        self.aceite="bajo"
        self.puertas="cerradas"
        if(self.gasolina=="ok" and self.aceite=="ok" and self.puertas=="cerradas"):
            return True
        else:
            return False
        
               
micoche=coche()

print(micoche.arrancar(True))
micoche.estado()

print(".........introducimos un segundo objeto.........")

micoche2=coche()

print(micoche2.arrancar(False))
micoche.estado()
print(micoche2.chequeo())
# Out:
# se va a proceder a chequear el coche
# algo ha ido mal en el chequeo.No debemos arrancar
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# .........introducimos un segundo objeto.........
# el coche esta parado
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# se va a proceder a chequear el coche
# False

# %%
#por eso deberiamos encapsular este metodo para que no ocurra esto
#si dejamos la orden anterior da el error

# %%
class coche():
    def __init__(self):
        self.largochasis=250
        self.anchochasis=120
        self.__ruedas=4
        self.enmarcha=False
        
    def arrancar(self,arrancamos):
        self.enmarcha=arrancamos
        if (self.enmarcha):
            chequeado=self.__chequeo()
        if (self.enmarcha and chequeado):
            return("el coche esta en marcha")
        elif (self.enmarcha and chequeado==False):
            return "algo ha ido mal en el chequeo.No debemos arrancar"
        
        else:
            return("el coche esta parado")
        
    def estado(self):
        print("el coche tiene ",self.__ruedas, "ruedas,","un ancho de ",self.anchochasis,
              "y","un largo de",self.largochasis)
        
    def __chequeo(self):
        print("se va a proceder a chequear el coche")
        self.gasolina="ok"
        self.aceite="bajo"
        self.puertas="cerradas"
        if(self.gasolina=="ok" and self.aceite=="ok" and self.puertas=="cerradas"):
            return True
        else:
            return False
        
               
micoche=coche()

print(micoche.arrancar(True))
micoche.estado()

print(".........introducimos un segundo objeto.........")

micoche2=coche()

print(micoche2.arrancar(False))
micoche.estado()
print(micoche2.chequeo())
# Out:
# se va a proceder a chequear el coche
# algo ha ido mal en el chequeo.No debemos arrancar
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# .........introducimos un segundo objeto.........
# el coche esta parado
# el coche tiene  4 ruedas, un ancho de  120 y un largo de 250
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-dff07c0f0e15> in <module>
#      42 print(micoche2.arrancar(False))
#      43 micoche.estado()
# ---> 44 print(micoche2.chequeo())
#
# AttributeError: 'coche' object has no attribute 'chequeo'
